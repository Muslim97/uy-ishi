# %%
n = int(input('butun son  '))
yuzmil1=n//1000000
yuzmil=n//1000000//100
onmil1=n//1000000
onmil=n//1000000%100//10
mil=n//1000000
mil=n//1000000%100%10
yuzming1=n//1000
yuzming=n%1000000//100000
onming1=n//1000
onming=n%1000000%100000//10000
ming=n%1000000%100000%10000//1000
yuz=n%1000//100
on=n%100//10
bir=n%10


if yuzmil1==100:
    print('yuz million',end=' ')
elif yuzmil == 1:
    print(" yuz ",end=' ')
if yuzmil1==200:
    print('ikkiyuzmillion',end=' ')
elif yuzmil == 2:
    print("ikki yuz",end=' ')
if yuzming1==300:
    print('uchyuzmillion',end=' ')
elif yuzmil == 3:
    print("uch yuz ",end=' ')
if yuzmil1==400:
    print('to`rtyuzmillion',end=' ')
elif yuzmil == 4:
    print("to'rt yuz ",end=' ')
if yuzmil1==500:
    print('beshyuzmillion',end=' ')
elif yuzmil == 5:
    print("besh yuz ",end=' ')
if yuzmil1==600:
    print('oltiyuzmillion',end=' ')
elif yuzmil == 6:
    print("olti yuz ",end=' ')
if yuzmil1==700:
    print('ettiyuzmillion',end=' ')
elif yuzmil == 7:
    print("yetti yuz ",end=' ')
if yuzmil1==800:
    print('sakkizyuzmillion',end=' ')
elif yuzmil == 8:
    print("sakkiz yuz ",end=' ')
if yuzmil1==900:
    print('toqqizyuzmillion',end=' ')
elif yuzmil == 9:
    print("to'qqiz yuz ",end=' ')    
    
if onmil1==10:
    print('on million',end=' ')
elif onmil == 1:
        print("on ",end=' ')
if onmil1==20:
    print('yigirmamillion',end=' ')
elif onmil == 2:
    print("yigirma ",end=' ')
if onmil1==30:
    print('ottizmillion',end=' ')
elif onmil == 3:
    print("o`ttiz ",end=' ')
if onmil1==40:
    print('qirqmillion',end=' ')
elif onmil == 4:
    print("qirq ",end=' ')
if onmil1==50:
    print('ellikmillion',end=' ')
elif onmil == 5:
    print("ellik ",end=' ')
if onmil1==60:
    print('oltmishmillion',end=' ')
elif onmil == 6:
    print("oltmish ",end=' ')
if onmil1==70:
    print('etmishmillion',end=' ')
elif onmil == 7:
    print("yetmish",end=' ')
if onmil1==80:
    print('saksonmillion',end=' ')
elif onmil == 8:
    print("sakson ",end=' ')
if onmil1==90:
    print('toqsonmillion',end=' ')
elif onmil == 9:
    print("to'qson",end=' ')

    
if mil == 1:
    print("bir million",end=' ')
if mil == 2:
    print("ikki million",end=' ')
if mil == 3:
    print("uch million",end=' ')
if mil == 4:
    print("to'rt million",end=' ')
if mil == 5:
    print("besh million",end=' ')
if mil == 6:
    print("olti million",end=' ')
if mil == 7:
    print("yetti million",end=' ')
if mil == 8:
    print("sakkiz million",end=' ')
if mil == 9:
    print("to'qqiz million",end=' ')

if yuzming1==100:
    print('yuz ming',end=' ')
elif yuzming == 1:
    print("yuz",end=' ')
if yuzming1==200:
    print('ikkiyuzming',end=' ')
elif yuzming == 2:
    print("ikki yuz ",end=' ')
if yuzming1==300:
    print('uchyuzming',end=' ')        
elif yuzming == 3:
    print("uch yuz ",end=' ')
if yuzming1==400:
    print('to`rtyuzming',end=' ')
elif yuzming == 4:
    print("to'rt yuz",end=' ')
if yuzming1==500:
    print('beshyuzming',end=' ')
elif yuzming == 5:
    print("besh yuz ",end=' ')
if yuzming1==600:
    print('oltiyuzming',end=' ')
elif yuzming == 6:
    print("olti yuz ",end=' ')
if yuzming1==700:
    print('ettiyuzming',end=' ')
elif yuzming == 7:
    print("yetti yuz ",end=' ')
if yuzming1==800:
    print('sakkizyuzming',end=' ')
elif yuzming == 8:
    print("sakkiz yuz ",end=' ')
if yuzming1==900:
    print('toqqizyuzming',end=' ')
elif yuzming == 9:
    print("to'qqiz yuz ",end=' ')    
    
    
if onming1==10:
    print('on ming',end=' ')
elif onming == 1:
    print("on ",end=' ')
if onming1==20:
    print('yigirma ming',end=' ')
elif onming == 2:
    print("yigirma ",end=' ')
if onming1==30:
    print('ottizming',end=' ')
elif onming == 3:
    print("ottiz ",end=' ')
if onming1==40:
    print('qirqming',end=' ')
elif onming == 4:
    print("qirq ",end=' ')
if onming1==50:
    print('ellikming',end=' ')
elif onming == 5:
    print("ellik ",end=' ')
if onming1==60:
    print('oltmishming',end=' ')
elif onming == 6:
    print("oltmish ",end=' ')
if onming1==70:
    print('yetmishming',end=' ')
elif onming == 7:
    print("yetmish ",end=' ')
if onming1==80:
    print('saksonming',end=' ')
elif onming == 8:
    print("sakson ",end=' ')
if onming1==90:
    print('toqsonming',end=' ')
elif onming == 9:
    print("to'qson ",end=' ')
    
    
if ming == 1:
    print("bir ming",end=' ')
if ming == 2:
    print("ikki ming",end=' ')
if ming == 3:
    print("uch ming",end=' ')
if ming == 4:
    print("to'rt ming",end=' ')
if ming == 5:
    print("besh ming",end=' ')
if ming == 6:
    print("olti ming",end=' ')
if ming == 7:
    print("yetti ming",end=' ')
if ming == 8:
    print("sakkiz ming",end=' ')
if ming == 9:
    print("to'qqiz ming",end=' ')
    
    
if yuz == 1:
    print("bir yuz",end=' ')
if yuz == 2:
    print("ikki yuz",end=' ')
if yuz == 3:
    print("uch yuz",end=' ')
if yuz == 4:
    print("to'rt yuz",end=' ')
if yuz == 5:
    print("besh yuz",end=' ')
if yuz == 6:
    print("olti yuz",end=' ')
if yuz == 7:
    print("yetti yuz",end=' ')
if yuz == 8:
    print("sakkiz yuz",end=' ')
if yuz == 9:
    print("to'qqiz yuz",end=' ')

if on == 1:
    print("o'n",end=' ')
if on == 2:
    print("yigirma",end=' ')
if on == 3:
    print("o'ttiz",end=' ')
if on == 4:
    print("qirq",end=' ')
if on == 5:
    print("ellik",end=' ')
if on == 6:
    print("oltmish",end=' ')
if on == 7:
    print("yetmish",end=' ')
if on == 8:
    print("sakson",end=' ')
if on == 9:
    print("to'qson",end=' ')
    
if bir == 1:
    print("bir",end=' ')
if bir == 2:
    print("ikki",end=' ')
if bir == 3:
    print("uch",end=' ')
if bir == 4:
    print("to'rt",end=' ')
if bir == 5:
    print("besh",end=' ')
if bir == 6:
    print("olti",end=' ')
if bir == 7:
    print("yetti",end=' ')
if bir == 8:
    print("sakkiz",end=' ')
if bir == 9:
    print("to'qqiz",end=' ')
    
if n==0:
    print('nolga teng')

# %%
#11
# 1-shimol, 2-janub , 3-sharq, 4-g`arb  /////   0-o`ngga, 1- chapka, 2-180gradusga

c=int(input('1-4 boshlang`ich holat:'))
k1=int(input('0-2 komandalar K1:'))
k2=int(input('0-2 komandalar K2:'))
if c==1:
    if k1==0 and k2==1 or k1==1 and k2==0 or k1==2 and k2==2:
        holat='Shimol'
    if k1==2 and k2==0 or k1==0 and k2==2:
        holat='G`arb'
    if k1==2 and k2==1 or k1==1 and k2==2:
        holat='Sharq'
    if k1==1 and k2==1 or k1==0 and k2==0:
        holat:'Janub'
    else:
        holat='Xato'

elif c==2:
    if k1==0 and k2==1 or k1==1 and k2==0 or k1==2 and k2==2:
        holat='Janub'
    if k1==2 and k2==0 or k1==0 and k2==2:
        holat='Sharq'
    if k1==2 and k2==1 or k1==1 and k2==2:
        holat='G`arb'
    if k1==1 and k2==1 or k1==0 and k2==0:
        holat:'Shimol'          
    else:
        holat='Xato'
elif c==3:
    if k1==0 and k2==1 or k1==1 and k2==0 or k1==2 and k2==2:
        holat='Sharq'
    if k1==2 and k2==0 or k1==0 and k2==2:
        holat='Shimol'
    if k1==2 and k2==1 or k1==1 and k2==2:
        holat='Janub'
    if k1==1 and k2==1 or k1==0 and k2==0:
        holat:'G`arb'
    else:
        holat='Xato'        
elif c==4:
    if k1==0 and k2==1 or k1==1 and k2==0 or k1==2 and k2==2:
        holat='G`arb'
    if k1==2 and k2==0 or k1==0 and k2==2:
        holat='Janub'
    if k1==2 and k2==1 or k1==1 and k2==2:
        holat='Shimol'
    if k1==1 and k2==1 or k1==0 and k2==0:
        holat:'Sharq'
    else:
        holat='Xato'
else:
    holat='Xato'
print(holat)

# %%
#9 case

d = int(input('d = '))
m = int(input('m = '))
y = int(input('y = '))

kabisa = False
if y%4==0:
    kabisa=True
if y%100==0 and y%400!=0:
    kabisa=False

d=d+1

if m==1 or m==3 or m==5 or  m==7 or m==8 or m==10 or m==12:
    if d==32:
        d=1
        m+=1
elif m==2:
    if kabisa==True and d==30:
        d=1
        m+=1
    if kabisa==False and d==29:
        d=1
        m+=1
    
else:
    if d==31:
        d=1
        m+=1
if m==13:
    m=1
    y+=1
print(d,m,y, sep=".")
